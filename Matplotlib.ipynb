# %%
import matplotlib.pyplot as plt

# %%
#plot, scatter

# %%
year = [1950,1970,1990,2010]
pop = [2.25,3.6,5.2,7]

# %%
plt.plot(year, pop)
plt.show()

# %%
plt.scatter(year, pop)
plt.show()

# %%
#Histograms

# %%
v = [0,0.6,1.4,1.6,2.2,2.5,6.7,3.2,1.1,2.3]

# %%
plt.hist(v, bins = 3)
# Out:
# (array([6., 3., 1.]),
#  array([0.        , 2.23333333, 4.46666667, 6.7       ]),
#  <a list of 3 Patch objects>)
